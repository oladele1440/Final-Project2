# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

starbucks_census = pd.read_csv('Datasets/starbucks_vs_cafe_count.csv')
starbucks_census.head()
# Out:
#   State/Province  Postcode  Starbucks Count             City Country  \
# 0             AK   99501.0                2        Anchorage      US
# 1             AK   99502.0                4        Anchorage      US
# 2             AK   99503.0                1        Anchorage      US
# 3             AK   99504.0                5        Anchorage      US
# 4             AK   99505.0                1  Fort Richardson      US
#
#    Latitude  Longitude  Population  Median Age  Household Income  \
# 0     61.22    -149.89        17.0        38.3           54579.0
# 1     61.18    -149.95        24.0        32.8           87250.0
# 2     61.18    -149.88        14.0        34.0           46819.0
# 3     61.23    -149.74        42.0        31.3           77132.0
# 4     61.26    -149.68         6.0        21.6           51582.0
#
#    Per Capita Income  Cafe Count
# 0            39690.0           0
# 1            39021.0           0
# 2            27693.0           0
# 3            31811.0           0
# 4            19267.0           0

# %%
data = starbucks_census[['State/Province','Starbucks Count','Median Age', 'Cafe Count','Household Income','Per Capita Income', 'Population']]
data.head()
# Out:
#   State/Province  Starbucks Count  Median Age  Cafe Count  Household Income  \
# 0             AK                2        38.3           0           54579.0
# 1             AK                4        32.8           0           87250.0
# 2             AK                1        34.0           0           46819.0
# 3             AK                5        31.3           0           77132.0
# 4             AK                1        21.6           0           51582.0
#
#    Per Capita Income  Population
# 0            39690.0        17.0
# 1            39021.0        24.0
# 2            27693.0        14.0
# 3            31811.0        42.0
# 4            19267.0         6.0

# %%
feature_names = data.columns
data.tail()
# Out:
#      State/Province  Starbucks Count  Median Age  Cafe Count  \
# 6042             WY                1        33.8           0
# 6043             WY                1        31.8           0
# 6044             WY                1        42.2           0
# 6045             WY                1        31.9           0
# 6046             WY                3        36.9           0
#
#       Household Income  Per Capita Income  Population binned
# 6042           69085.0            31354.0        18.0      0
# 6043           87873.0            35687.0        25.0      0
# 6044           54814.0            30054.0        25.0      0
# 6045           67698.0            29933.0        29.0      0
# 6046           74942.0            44521.0        17.0      0

# %%
data['binned'] = pd.cut(data['Starbucks Count'], bins=[0, 3, 9, 12, 15, float('Inf')], labels=[0, 1, 2,3, 4])
data.head()
# Out:
# C:\Users\lawre\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#   State/Province  Starbucks Count  Median Age  Cafe Count  Household Income  \
# 0             AK                2        38.3           0           54579.0
# 1             AK                4        32.8           0           87250.0
# 2             AK                1        34.0           0           46819.0
# 3             AK                5        31.3           0           77132.0
# 4             AK                1        21.6           0           51582.0
#
#    Per Capita Income  Population binned
# 0            39690.0        17.0      0
# 1            39021.0        24.0      1
# 2            27693.0        14.0      0
# 3            31811.0        42.0      1
# 4            19267.0         6.0      0

# %%
data.describe()
# Out:
#        Starbucks Count   Median Age   Cafe Count  Household Income  \
# count      6047.000000  6047.000000  6047.000000       6047.000000
# mean          2.250207    35.589218     0.000331      59982.479246
# std           1.903582    11.271898     0.025719      30896.145796
# min           1.000000     0.000000     0.000000          0.000000
# 25%           1.000000    33.000000     0.000000      42815.500000
# 50%           2.000000    37.200000     0.000000      56840.000000
# 75%           3.000000    41.400000     0.000000      76415.500000
# max          32.000000    89.500000     2.000000     250001.000000
#
#        Per Capita Income   Population
# count        6047.000000  6047.000000
# mean        31317.507028    27.499752
# std         17383.674451    17.970966
# min             0.000000     0.000000
# 25%         22136.500000    15.000000
# 50%         28908.000000    26.000000
# 75%         38515.000000    38.000000
# max        184886.000000   114.000000

# %%
data.corr()
# Out:
#                    Starbucks Count  Median Age  Cafe Count  Household Income  \
# Starbucks Count           1.000000    0.066498   -0.008447          0.187418
# Median Age                0.066498    1.000000    0.008798          0.539295
# Cafe Count               -0.008447    0.008798    1.000000          0.017106
# Household Income          0.187418    0.539295    0.017106          1.000000
# Per Capita Income         0.266557    0.572726    0.008564          0.836472
# Population                0.275425    0.204840    0.006799          0.195212
#
#                    Per Capita Income  Population
# Starbucks Count             0.266557    0.275425
# Median Age                  0.572726    0.204840
# Cafe Count                  0.008564    0.006799
# Household Income            0.836472    0.195212
# Per Capita Income           1.000000    0.057534
# Population                  0.057534    1.000000

# %%
# starbucks_census['buckets'] = pd.cut(starbucks_census['Cafe Count'], bins=[0, 3, 9, float('Inf')], labels=[0, 1, 2])
# starbucks_census.head()

# %%
# starbucks_census['binned'] = pd.cut(starbucks_census['Starbucks Count'], bins=[0, 3, 9, float('Inf')], labels=['xxx', 'yyy', 'zzz'])
# starbucks_census.describe()

# %%
# missing_values = X==np.NAN
# X[missing_values==True].head()

# %%
# Assign the data to X and y
# Note: Sklearn requires a 7 x 1 array of values
# so we use reshape to create this

X = data[['Household Income', 'Population', 'Per Capita Income','Median Age', 'Cafe Count']]
y = data['binned']

print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (6047, 5) (6047,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.83531746031746035

# %%
sorted(zip(rf.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.28961098569616356, 'Per Capita Income'),
#  (0.26249788028321247, 'Household Income'),
#  (0.22705754953458843, 'Median Age'),
#  (0.22083358448603563, 'Population'),
#  (0.0, 'Cafe Count')]

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

# Use our model to predict a value
predicted = model.predict(X)

# Score the prediction with mse and r2
mse = mean_squared_error(y, predicted)
r2 = r2_score(y, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-153-037694e2ec22> in <module>()
#       3
#       4 # Use our model to predict a value
# ----> 5 predicted = predict(X)
#       6
#       7 # Score the prediction with mse and r2
#
# NameError: name 'predict' is not defined
