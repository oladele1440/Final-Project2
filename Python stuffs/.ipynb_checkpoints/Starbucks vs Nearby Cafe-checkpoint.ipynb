# %%
# import all the dependencies
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import requests as req
import time
from scipy.stats import norm

# %%
# Read the csv file starbucks_vs_cafe_count.csv
starbucks_usa = pd.read_csv("../Datasets/starbucks_vs_cafe_count.csv")
starbucks_usa.head()
# Out:
#   State/Province  Postcode  Starbucks Count             City Country  \
# 0             AK   99501.0                2        Anchorage      US
# 1             AK   99502.0                4        Anchorage      US
# 2             AK   99503.0                1        Anchorage      US
# 3             AK   99504.0                5        Anchorage      US
# 4             AK   99505.0                1  Fort Richardson      US
#
#    Latitude  Longitude  Population  Median Age  Household Income  \
# 0     61.22    -149.89     17213.0        38.3           54579.0
# 1     61.18    -149.95     23649.0        32.8           87250.0
# 2     61.18    -149.88     14107.0        34.0           46819.0
# 3     61.23    -149.74     42189.0        31.3           77132.0
# 4     61.26    -149.68      6479.0        21.6           51582.0
#
#    Per Capita Income  Cafe Count
# 0            39690.0           0
# 1            39021.0           0
# 2            27693.0           0
# 3            31811.0           0
# 4            19267.0           0

# %%
# State with most number of starbucks
starbucks_usa['State/Province'].value_counts().head(1)
# Out:
# CA    930
# Name: State/Province, dtype: int64

# %%
# Top 20 States in USA based on number of stores
starbucks_usa['State/Province'].value_counts().head(20)
# Out:
# CA    930
# TX    446
# FL    353
# NY    301
# IL    236
# WA    224
# MA    217
# NJ    211
# PA    201
# OH    193
# AZ    177
# CO    171
# VA    171
# NC    152
# GA    152
# MI    146
# OR    119
# MD    116
# IN    113
# CT    112
# Name: State/Province, dtype: int64

# %%
# Create a plot for top 20 states in USA based on number of stores
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.set(title="Top 20 States in USA with most number of stores")
starbucks_usa['State/Province'].value_counts().head(20).plot(kind="bar", color='green')
# starbucks_usa['State/Province'].value_counts().head(25).plot(kind="bar")
plt.savefig("Number of Starbucks in Top 20 States(USA).png")
plt.show()

# %%
# Read another csv file with additional data (census data)
starbucks_usa_df = pd.read_csv("State_Zip.csv")
# Visualize
starbucks_usa_df.tail()
# Out:
#       Unnamed: 0 State/Province  Postcode  Store Number          City Country  \
# 6042        6042             WY   82716.0             1      Gillette      US
# 6043        6043             WY   82718.0             1      Gillette      US
# 6044        6044             WY   82801.0             1     Sheridian      US
# 6045        6045             WY   82901.0             1  Rock Springs      US
# 6046        6046             WY   83001.0             3  Jackson Hole      US
#
#       Population  Median Age  Household Income  Per Capita Income  \
# 6042     18189.0        33.8           69085.0            31354.0
# 6043     25335.0        31.8           87873.0            35687.0
# 6044     24933.0        42.2           54814.0            30054.0
# 6045     29302.0        31.9           67698.0            29933.0
# 6046     16625.0        36.9           74942.0            44521.0
#
#            ...         Race White  Race African American  \
# 6042       ...            17022.0                  186.0
# 6043       ...            23635.0                  189.0
# 6044       ...            23192.0                  229.0
# 6045       ...            26855.0                  300.0
# 6046       ...            15345.0                   45.0
#
#       Race American Indian  Race Asian  Race Pacific Islander  \
# 6042                  52.0       100.0                    0.0
# 6043                 442.0       202.0                    0.0
# 6044                 270.0       227.0                   18.0
# 6045                  99.0       324.0                  229.0
# 6046                 105.0       332.0                    0.0
#
#       Race Two or More  ageCategory  ageBinned  householdCategory  \
# 6042             540.0            2   (18, 35]                  2
# 6043             897.0            2   (18, 35]                  2
# 6044             952.0            3   (35, 55]                  2
# 6045            2109.0            2   (18, 35]                  2
# 6046             356.0            3   (35, 55]                  2
#
#       householdBinned
# 6042  (60000, 120000]
# 6043  (60000, 120000]
# 6044       (0, 60000]
# 6045  (60000, 120000]
# 6046  (60000, 120000]
#
# [5 rows x 23 columns]

# %% [markdown]
# # Spread of Starbucks Stores in USA as per location : Longitude vs Latitude

# %%
# Create a plot to show the spread of Starbucks stores throughout the country(USA)

# Create lists for coordinates
longitude = list(starbucks_usa_df["Longitude"])
latitude = list(starbucks_usa_df["Latitude"])

g = sns.JointGrid(x="Longitude", y="Latitude", data=starbucks_usa_df, size=10)
g = g.plot_joint(plt.scatter, color="g", edgecolor="white")
g = g.plot_marginals(sns.distplot, kde=False, color="g")

# Chart title
plt.title("Spread of Starbucks Stores in USA")
# x label
plt.xlabel("Longitude")
# y label
plt.ylabel("Latitude")
# Legend
plt.legend("")

# Save an image of the chart and print to screen
plt.savefig("Spread of Starbucks Stores in USA")
plt.show()
# Out:
# C:\Users\lawre\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # How competitive is the coffee shop market in regards to Starbucks?
# Total number of Starbucks vs Nearby Cafes

# %%
# Read the csv file starbucks_vs_cafe_count.csv
starbucks_vs_cafe_count = pd.read_csv("../Datasets/starbucks_vs_cafe_count.csv")
starbucks_vs_cafe_count = starbucks_vs_cafe_count.rename(columns={"Starbucks Count":"Starbucks","Cafe Count":"Nearby Cafes"})
# Visualize the data frame
starbucks_vs_cafe_count.tail()
# Out:
#      State/Province  Postcode  Starbucks          City Country  Latitude  \
# 6042             WY   82716.0          1      Gillette      US     44.28
# 6043             WY   82718.0          1      Gillette      US     44.27
# 6044             WY   82801.0          1     Sheridian      US     44.77
# 6045             WY   82901.0          1  Rock Springs      US     41.58
# 6046             WY   83001.0          3  Jackson Hole      US     43.48
#
#       Longitude  Population  Median Age  Household Income  Per Capita Income  \
# 6042    -105.49     18189.0        33.8           69085.0            31354.0
# 6043    -105.49     25335.0        31.8           87873.0            35687.0
# 6044    -106.94     24933.0        42.2           54814.0            30054.0
# 6045    -109.25     29302.0        31.9           67698.0            29933.0
# 6046    -110.75     16625.0        36.9           74942.0            44521.0
#
#       Nearby Cafes
# 6042             0
# 6043             0
# 6044             0
# 6045             0
# 6046             0

# %%
fig = plt.figure(figsize=(12,8))
plt.scatter(starbucks_vs_cafe_count['Postcode'], starbucks_vs_cafe_count['Nearby Cafes'], alpha=0.7, edgecolor='black', c="orange", label="Nearby Cafes")

plt.scatter(starbucks_vs_cafe_count['Postcode'], starbucks_vs_cafe_count['Starbucks'], alpha=0.3, edgecolor='black', c="green", label="Starbucks Count")

plt.legend(loc="upper left", frameon=True, fontsize=10)
plt.xlabel("Zip Code")
plt.ylabel("Count")
plt.title("Starbucks vs Nearby Cafes")
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig("Starbucks vs Nearby Cafes.png")

# %% [markdown]
# # Average number of Starbucks and nearby cafes per state

# %%
# Create a dataframe grouped by states with number starbucks and nearby cafes
groupby_states = starbucks_vs_cafe_count.groupby("State/Province").aggregate({"Starbucks":"mean", "Nearby Cafes":"mean"})
# Export the dataframe to csv
groupby_states.to_csv("groupby_states.csv", index=False)
groupby_states.head()
# Out:
#                 Starbucks  Nearby Cafes
# State/Province
# AK               2.130435             0
# AL               1.700000             0
# AR               1.527778             0
# AZ               2.757062             0
# CA               3.033333             0

# %%
groupby_states.plot(kind="bar", figsize=(20,10), color=('g','y'), stacked=True,
                    title="Relationship between Starbucks Brand and Nearby Cafes")

plt.savefig("Relationship between Starbucks Brand and Nearby Cafes.png")
plt.show()

# %% [markdown]
# # Percentage of Starbucks Stores per state

# %%
# Ratio between Other cafes and Starbucks
percentage_of_starbucks = (groupby_states["Starbucks"] / (groupby_states["Starbucks"] + groupby_states["Nearby Cafes"] ) ) * 100
# Export the dataframe to csv
percentage_of_starbucks.to_csv("percentage_of_starbucks.csv", index=False)
percentage_of_starbucks.head()
# Out:
# State/Province
# AK    100.0
# AL    100.0
# AR    100.0
# AZ    100.0
# CA    100.0
# dtype: float64

# %%
# percentage_of_starbucks.plot(kind="bar", figsize=(25, 15), align='edge', alpha=.8, color = 'g')
# plt.title("Percentage of Starbucks Store" , fontsize= 20)
# plt.xlabel("State", fontsize= 20)
# plt.ylabel("Percentage(%)", fontsize= 20)
# plt.savefig("Percentage of Starbucks Store.png")
# plt.show()
